# %% [markdown]
# # SQL prọject
#
# ## Tạo SQL project
#
# Các bước :
#
#   - File
#
# - New
#
# - Project (hoặc **Ctrl + Shift + N**)
#
# - Chọn SQL Server Scripts -> đặt tên và đường dẫn
#
# ![](Images/6_pro1.png)
#
# ![](Images/6_pro2.png)
#
#
# ## Tạo connection và queries :
#
# Các bước :
#
#   - Mở màn hình Solution Explorer **(Ctrl + Alt + L)**
#
#   - Connections -> New connection
#
# - Queries -> New Query
#
# ![Mở màn hình Solution Explorer](Images/6_pro4.png)
#
# ![](Images/6_pro3.png)
#
# - Tạo connection :
#
#   ![](Images/6_pro5.png)
#
# ![](Images/6_pro6.png)
#
# - Tạo query
#
# ![](Images/6_pro7.png)
#
# ![](Images/6_pro72.png)
#
# ## Đóng project
#
# **File -> Close Solution**
#
#   ![](Images/6_pro8.png)
#
# ## Mở project đã có sẵn
#
# Các bước :
#
#   - File
#
# - Open
#
# - Project/Solution (hoặc **Ctrl + Shift + O**)
#
# - Mở đường dẫn tới project -> chọn file có đuôi **.ssmssqlproj**
#
# ![](Images/6_pro9.png)
#
# ![](Images/6_pro10.png)
